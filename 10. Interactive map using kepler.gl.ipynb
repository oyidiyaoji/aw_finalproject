# %% [markdown]
# # Building an interactive map with kepler.gl
#
# When I was doing my final project sometimes I felt stuck so I thought it was a good oportunity to try new things like kepler.gl. Although I already built a map I wanted to follow the instructions provided to see how impactful visualizations can be.
#
# In order to do it I had to search for the latitude and longitude of all the countries listed on my dataset no.2 and merge the information to get one dataset with all the information I need to create a map.
#
# You can find the steps I followed in this link: https://bit.ly/30VDOMS

# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv('/home/user/Documents/OYI_PC_2and3/TRABAJO/Allwomen/Projects/Final Project/csv_datasets/lati_longi_countries.csv')

# %%
data.head()
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
data.rename(columns={'country': 'abrv', 'name': 'Country'}, inplace=True)

# %%
data.head()
# Out:
#   abrv   latitude  longitude               Country
# 0   AD  42.546245   1.601554               Andorra
# 1   AE  23.424076  53.847818  United Arab Emirates
# 2   AF  33.939110  67.709953           Afghanistan
# 3   AG  17.060816 -61.796428   Antigua and Barbuda
# 4   AI  18.220554 -63.068615              Anguilla

# %%
social = pd.read_csv('/home/user/Documents/OYI_PC_2and3/TRABAJO/Allwomen/Projects/Final Project/csv_datasets/reduced_datasets/mfi_social.csv')

# %%
social.head()
# Out:
#    Unnamed: 0         MFI Name  Fiscal Year  \
# 0           0  1st Valley Bank         2011
# 1           1  1st Valley Bank         2012
# 2           2  1st Valley Bank         2013
# 3           3  1st Valley Bank         2014
# 4           4  1st Valley Bank         2018
#
#    Average loan balance per borrower / GNI per capita  Gross Loan Portfolio  \
# 0                                             0.5013             85055980.0
# 1                                             0.7125            112791709.0
# 2                                             0.7414            116329302.0
# 3                                             0.6669            116423597.0
# 4                                             0.8426            132682781.0
#
#    Gross Loan Portfolio > Delinquency > One month or more  \
# 0                                          4029479.0
# 1                                          6231245.0
# 2                                         10507132.0
# ...

# %%
social.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3661 entries, 0 to 3660
# Data columns (total 31 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Unnamed: 0                                              3661 non-null   int64
#  1   MFI Name                                                3661 non-null   object
#  2   Fiscal Year                                             3661 non-null   int64
#  3   Average loan balance per borrower / GNI per capita      3661 non-null   float64
#  4   Gross Loan Portfolio                                    3661 non-null   float64
#  5   Gross Loan Portfolio > Delinquency > One month or more  3661 non-null   float64
#  6   Number of active borrowers                              3661 non-null   float64
#  7   Offices                                                 3661 non-null   float64
# ...

# %%
map = pd.merge(social, data, how='inner')

# %%
map.head()
# Out:
#    Unnamed: 0         MFI Name  Fiscal Year  \
# 0           0  1st Valley Bank         2011
# 1           1  1st Valley Bank         2012
# 2           2  1st Valley Bank         2013
# 3           3  1st Valley Bank         2014
# 4           4  1st Valley Bank         2018
#
#    Average loan balance per borrower / GNI per capita  Gross Loan Portfolio  \
# 0                                             0.5013             85055980.0
# 1                                             0.7125            112791709.0
# 2                                             0.7414            116329302.0
# 3                                             0.6669            116423597.0
# 4                                             0.8426            132682781.0
#
#    Gross Loan Portfolio > Delinquency > One month or more  \
# 0                                          4029479.0
# 1                                          6231245.0
# 2                                         10507132.0
# ...

# %%
map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3566 entries, 0 to 3565
# Data columns (total 34 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Unnamed: 0                                              3566 non-null   int64
#  1   MFI Name                                                3566 non-null   object
#  2   Fiscal Year                                             3566 non-null   int64
#  3   Average loan balance per borrower / GNI per capita      3566 non-null   float64
#  4   Gross Loan Portfolio                                    3566 non-null   float64
#  5   Gross Loan Portfolio > Delinquency > One month or more  3566 non-null   float64
#  6   Number of active borrowers                              3566 non-null   float64
#  7   Offices                                                 3566 non-null   float64
# ...

# %%
map.drop(['Unnamed: 0', 'abrv'], axis=1, inplace=True)

# %%
map.shape
# Out:
# (3566, 32)

# %%
pip install keplergl
# Out:
# ...
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/user/my-project-env/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gepd
import keplergl

# %%
df = map.copy()

# %%
# lat and lon to numeric, errors converted to nan
df['LONGITUDE'] = pd.to_numeric(df.longitude, errors='coerce')
df['LATITUDE'] = pd.to_numeric(df.latitude, errors='coerce')
# drop rows with missing lat and lon
df.dropna(subset=['longitude', 'latitude'], inplace=True)

# %%
kepler_map = keplergl.KeplerGl(height=400)
kepler_map
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()

# %%
kepler_map.add_data(data=df, name="mfi")
